# %% [markdown]
# <a href="https://colab.research.google.com/github/aLL3H/cluster/blob/main/Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
from hopkins import *
from metric import *
from visual_assessment_of_tendency import *

# %%
import warnings
warnings.filterwarnings("ignore", category = FutureWarning)

# %%
iris = datasets.load_iris()
clust1 = scale(iris.data)
clust2 = scale(np.random.rand(150,4))

# %%
print(clust2)

# %%
inertia = []
for i in range(1,8):
  kmeans = KMeans(n_clusters=i, n_init = "auto")
  kmeans.fit(clust1)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title("Elbow")
plt.show()

# %%
inertia = []
for i in range(1,8):
  kmeans = KMeans(n_clusters=i, n_init = "auto")
  kmeans.fit(clust2)
  inertia.append(kmeans.inertia_)
plt.plot(range(1,8), inertia)
plt.title("Elbow")
plt.show()

# %%
hopkins(clust1, 150)
# Out:
# 0.1879738368219165

# %%
hopkins(clust2, 150)
# Out:
# 0.5077606723442114

# %%
vat(clust1)

# %%
vat(clust2)

# %%
ivat(clust1)

# %%
ivat(clust2)

# %%
#m = assess_tendency_by_metric(clust1, 'silhouette', 5)
#m = assess_tendency_by_metric(clust1, 'davies_bouldin', 5)
m = assess_tendency_by_metric(clust1, 'calinski_harabasz', 5)
print(m)
# Out:
# (2, array([251.34933946, 241.9044017 , 207.26591432, 203.20025282]))

# %%
#m = assess_tendency_by_metric(clust2, 'silhouette', 5)
#m = assess_tendency_by_metric(clust2, 'davies_bouldin', 5)
m = assess_tendency_by_metric(clust2, 'calinski_harabasz', 5)
print(m)
# Out:
# (2, array([42.51191567, 39.67675761, 40.84396392, 41.04029072]))

# %%
m = assess_tendency_by_mean_metric_score(clust1,5)
print(m)
# Out:
# 2.0

# %%
m = assess_tendency_by_mean_metric_score(clust2,5)
print(m)
# Out:
# 4.0
